# %%
# Business Problem  - Areofit Treadmill

# %%
# Importing modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('aerofit_treadmill.csv')

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.shape
# Out:
# (180, 9)

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df_desb = df.describe()
mean_values = df_desb.loc['mean']
mean_values
# Out:
# Age             28.788889
# Education       15.572222
# Usage            3.455556
# Fitness          3.311111
# Income       53719.577778
# Miles          103.194444
# Name: mean, dtype: float64

# %%
plt.plot(mean_values )

# %%
sns.pairplot(data=df , hue='Product')

# %%
sns.countplot(data=df , x='Gender' , hue='Product')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.boxplot(data=df ,x='Gender' , y='Usage'  , hue='Product')
# Out:
# <Axes: xlabel='Gender', ylabel='Usage'>

# %%
sns.boxplot(data=df ,x='Product' , y='Usage'  , hue='Gender')
# Out:
# <Axes: xlabel='Product', ylabel='Usage'>

# %%
sns.lineplot(data=df , x='Education' , y='Usage' )
# Out:
# <Axes: xlabel='Education', ylabel='Usage'>

# %%
sns.scatterplot(data=df , x='Product' , y='Fitness' , hue='Age')
# Out:
# <Axes: xlabel='Product', ylabel='Fitness'>

# %%
sns.displot(df['Product'])

# %%
sns.displot(df['Age'])

# %%
sns.barplot(data=df , x='Income' , y='Miles' , hue='Fitness'  ,gap=1 , color='red')
# Out:
# C:\Users\r555s\AppData\Local\Temp\ipykernel_8968\2236717953.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.barplot(data=df , x='Income' , y='Miles' , hue='Fitness'  ,gap=1 , color='red')

# %%
sns.relplot(data=df , x='Age' , y='Income', col='Product' , hue='Gender' , style='Gender')

# %%
sns.relplot(data=df , x='Product' , y='Income', col='Gender' , hue='MaritalStatus' )
