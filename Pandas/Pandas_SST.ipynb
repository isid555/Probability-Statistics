# %%
import numpy as np
import pandas as pd

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 70.5MB/s]

# %%
data = pd.read_csv('movies.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
pd.Series([1, 4, 6, 2])
# Out:
# 0    1
# 1    4
# 2    6
# 3    2
# dtype: int64

# %%
nums = np.random.randint(1, 10, size=(5, 4))
nums
# Out:
# array([[9, 6, 8, 8],
#        [9, 5, 2, 4],
#        [7, 2, 5, 3],
#        [3, 8, 9, 3],
#        [8, 4, 2, 3]])

# %%
df = pd.DataFrame(nums)
df
# Out:
#    0  1  2  3
# 0  9  6  8  8
# 1  9  5  2  4
# 2  7  2  5  3
# 3  3  8  9  3
# 4  8  4  2  3

# %%
# 1465 movies.
data.shape
# Out:
# (1465, 12)

# %%
data.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
data.head(3)
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday

# %%
data.head(10)
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
# 5           9  43606  250000000         155   873260194
# 6          10  43607  270000000          57   391081192
# 7          11  43608  200000000         107   586090727
# 8          12  43609  200000000         145  1065659812
# 9          13  43610  255000000          49    89289910
#
#                                         title  vote_average  vote_count  \
# 0                                      Avatar           7.2       11800
# 1    Pirates of the Caribbean: At World's End           6.9        4500
# 2                                     Spectre           6.3        4466
# ...

# %%
data.tail(2)
# Out:
#       Unnamed: 0     id  budget  popularity  revenue        title  \
# 1463        4749  48376       0           3        0      Slacker
# 1464        4768  48395  220000          14  2040920  El Mariachi
#
#       vote_average  vote_count  director_id  year month     day
# 1463           6.4          77         5535  1990   Jul  Friday
# 1464           6.6         238         5097  1992   Sep  Friday

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1465 non-null   int64
#  1   id            1465 non-null   int64
#  2   budget        1465 non-null   int64
#  3   popularity    1465 non-null   int64
#  4   revenue       1465 non-null   int64
#  5   title         1465 non-null   object
#  6   vote_average  1465 non-null   float64
#  7   vote_count    1465 non-null   int64
#  8   director_id   1465 non-null   int64
#  9   year          1465 non-null   int64
#  10  month         1465 non-null   object
#  11  day           1465 non-null   object
# dtypes: float64(1), int64(8), object(3)
# memory usage: 137.5+ KB

# %%
data.describe()
# Out:
#         Unnamed: 0            id        budget   popularity       revenue  \
# count  1465.000000   1465.000000  1.465000e+03  1465.000000  1.465000e+03
# mean   1627.391809  45225.191126  4.802295e+07    30.855973  1.432539e+08
# std    1187.182894   1189.096396  4.935541e+07    34.845214  2.064918e+08
# min       0.000000  43597.000000  0.000000e+00     0.000000  0.000000e+00
# 25%     639.000000  44236.000000  1.400000e+07    11.000000  1.738013e+07
# 50%    1425.000000  45022.000000  3.300000e+07    23.000000  7.578164e+07
# 75%    2393.000000  45990.000000  6.600000e+07    41.000000  1.792469e+08
# max    4768.000000  48395.000000  3.800000e+08   724.000000  2.787965e+09
#
#        vote_average    vote_count  director_id         year
# count   1465.000000   1465.000000  1465.000000  1465.000000
# mean       6.368191   1146.396587  5040.192491  2002.615017
# std        0.818033   1578.077438   258.059631     8.680141
# min        3.000000      1.000000  4762.000000  1976.000000
# ...

# %%
data.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
# extracting columns
data['vote_average']
# Out:
# 0       7.2
# 1       6.9
# 2       6.3
# 3       7.6
# 4       5.9
#        ...
# 1460    7.9
# 1461    7.4
# 1462    6.0
# 1463    6.4
# 1464    6.6
# Name: vote_average, Length: 1465, dtype: float64

# %%
data['revenue']
# Out:
# 0       2787965087
# 1        961000000
# 2        880674609
# 3       1084939099
# 4        890871626
#            ...
# 1460        321952
# 1461       3151130
# 1462             0
# 1463             0
# 1464       2040920
# Name: revenue, Length: 1465, dtype: int64

# %%
data[['revenue', 'budget']]
# Out:
#          revenue     budget
# 0     2787965087  237000000
# 1      961000000  300000000
# 2      880674609  245000000
# 3     1084939099  250000000
# 4      890871626  258000000
# ...          ...        ...
# 1460      321952          0
# 1461     3151130      27000
# 1462           0          0
# 1463           0          0
# 1464     2040920     220000
#
# [1465 rows x 2 columns]

# %%
data['revenue'].min()
# Out:
# 0

# %%
data['budget'].min()
# Out:
# 0

# %%
# data

# %%
data['revenue'].max()
# Out:
# 2787965087

# %%
data['budget'].max()
# Out:
# 380000000

# %%
data['vote_average']
# Out:
# 0       7.2
# 1       6.9
# 2       6.3
# 3       7.6
# 4       5.9
#        ...
# 1460    7.9
# 1461    7.4
# 1462    6.0
# 1463    6.4
# 1464    6.6
# Name: vote_average, Length: 1465, dtype: float64

# %%
mask = data['vote_average'] > 7
mask
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1460     True
# 1461     True
# 1462    False
# 1463    False
# 1464    False
# Name: vote_average, Length: 1465, dtype: bool

# %%
data[mask]
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 3              3  43600  250000000         112  1084939099
# 14            19  43616  250000000         120   956019788
# 16            22  43619  250000000          94   958400000
# 19            25  43622  200000000         100  1845034188
# ...          ...    ...        ...         ...         ...
# 1456        4694  48321      10000          20     7000000
# 1457        4696  48323          0           5           0
# 1458        4708  48335      60000          27     3221152
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
#
#                                           title  vote_average  vote_count  \
# 0                                        Avatar           7.2       11800
# 3                         The Dark Knight Rises           7.6        9106
# ...

# %%
data[ data['vote_average'] < 4 ]
# Out:
#       Unnamed: 0     id    budget  popularity   revenue  \
# 164          272  43869  90000000           1  10372291
# 351          601  44198         0           9         0
# 549         1001  44598  50000000           8  12764201
# 812         1606  45203  30000000          10  84646831
# 896         1806  45403  26000000           5         0
# 944         1939  45536  25000000           7   2405420
# 1010        2113  45710  20000000          10  48548426
# 1012        2122  45719  20000000           6  86865564
# 1036        2194  45791  25000000          16  14109284
# 1058        2237  45834  20000000           9  10442808
# 1383        3853  47453   3500000           4         0
#
#                                       title  vote_average  vote_count  \
# 164                          Town & Country           3.7          16
# 351                              Rollerball           3.4         106
# 549   Street Fighter: The Legend of Chun-Li           3.9         112
# ...

# %%
data[ data['vote_average'] < 4 ].shape
# Out:
# (11, 12)

# %%
# extracting all the movies realsed in 2015 with rating greater than 7
data[ (data['year'] == 2015) & (data['vote_average']>7) ]
# Out:
#      Unnamed: 0     id     budget  popularity     revenue  \
# 30           44  43641  190000000         102  1506249360
# 78          127  43724  150000000         434   378858340
# 106         176  43773  135000000         100   532950503
# 162         270  43867  108000000         167   630161890
# 312         531  44128   75000000          48   108145109
# 394         684  44281   44000000          68   155760117
# 625        1173  44770   35000000          53   194564672
# 635        1187  44784   40000000          48   165478348
# 808        1597  45194   30000000          65    91709827
# 833        1696  45293   28000000          61   201634991
# 839        1704  45301   28000000          57   133346506
#
#                        title  vote_average  vote_count  director_id  year  \
# 30                 Furious 7           7.3        4176         4794  2015
# 78        Mad Max: Fury Road           7.2        9427         4845  2015
# ...

# %%
data[ (data['year'] == 2015)].shape
# Out:
# (41, 12)

# %%
data[ (data['year'] == 2016)].shape
# Out:
# (26, 12)

# %%
data[ (data['year'] == 2014)].shape
# Out:
# (53, 12)

# %%
data[ (data['year'] == 2013)].shape
# Out:
# (57, 12)

# %%
data[ (data['year'] == 1988)].shape
# Out:
# (13, 12)

# %%
data[ (data['year'] == 1999)].shape
# Out:
# (64, 12)

# %%
data
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
# top 5 highest rated  movies.
data.sort_values(by=['vote_average'], ascending = False)
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 1284        3232  46829    8000000         121   213928762
# 383          662  44259   63000000         146   100853753
# 901         1818  45415   22000000         104   321365567
# 459          809  44406   55000000         138   677945399
# 45            65  43662  185000000         187  1004558444
# ...          ...    ...        ...         ...         ...
# 351          601  44198          0           9           0
# 1383        3853  47453    3500000           4           0
# 1012        2122  45719   20000000           6    86865564
# 1058        2237  45834   20000000           9    10442808
# 1036        2194  45791   25000000          16    14109284
#
#                             title  vote_average  vote_count  director_id  \
# 1284                 Pulp Fiction           8.3        8428         4927
# 383                    Fight Club           8.3        9413         4829
# ...

# %%
data_vote_sorted = data.sort_values(by=['vote_average'], ascending = False)

# %%
data_vote_sorted[ data_vote_sorted['year']> 2000]
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 45            65  43662  185000000         187  1004558444
# 199          329  43926   94000000         123  1118888979
# 59            96  43693  160000000         167   825532764
# 58            95  43692  165000000         724   675120017
# 776         1532  45129   30000000          74   174600318
# ...          ...    ...        ...         ...         ...
# 351          601  44198          0           9           0
# 1383        3853  47453    3500000           4           0
# 1012        2122  45719   20000000           6    86865564
# 1058        2237  45834   20000000           9    10442808
# 1036        2194  45791   25000000          16    14109284
#
#                                               title  vote_average  vote_count  \
# 45                                  The Dark Knight           8.2       12002
# 199   The Lord of the Rings: The Return of the King           8.1        8064
# ...

# %%
data.sort_values(by=['year', 'vote_average'])
# Out:
#       Unnamed: 0     id     budget  popularity    revenue  \
# 912         1838  45435    2800000          25   60922980
# 1379        3809  47409    3800000          17   23689877
# 1427        4325  47934    1300000          58   28262574
# 1176        2693  46290          0           3          0
# 1357        3667  47265    5000000          11          0
# ...          ...    ...        ...         ...        ...
# 54            78  43675  175000000          94  966550600
# 225          370  43967   90000000          51  334901337
# 519          941  44538   50000000          42   69411370
# 617         1160  44757   40000000          68  320170008
# 1344        3584  47181    5000000          22   24804129
#
#                                           title  vote_average  vote_count  \
# 912                                    The Omen           7.2         476
# 1379                                    Network           7.7         381
# ...

# %%
data
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
data['revenue'] - data['budget']
# Out:
# 0       2550965087
# 1        661000000
# 2        635674609
# 3        834939099
# 4        632871626
#            ...
# 1460        321952
# 1461       3124130
# 1462             0
# 1463             0
# 1464       1820920
# Length: 1465, dtype: int64

# %%
# creating a new column ('Profit)

data['Profit'] =  data['revenue'] - data['budget']

# %%
data.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      Profit
# 0         4762  2009   Dec  Thursday  2550965087
# 1         4763  2007   May  Saturday   661000000
# 2         4764  2015   Oct    Monday   635674609
# ...

# %%
data.sort_values(by='Profit', ascending= False)
# Out:
#      Unnamed: 0     id     budget  popularity     revenue  \
# 0             0  43597  237000000         150  2787965087
# 19           25  43622  200000000         100  1845034188
# 30           44  43641  190000000         102  1506249360
# 199         329  43926   94000000         123  1118888979
# 36           52  43649  195000000          28  1123746996
# ..          ...    ...        ...         ...         ...
# 442         780  44377   80000000          14           0
# 480         845  44442   80000000           7           0
# 203         340  43937   98000000           7    10017322
# 127         208  43805  160000000          27    61698899
# 9            13  43610  255000000          49    89289910
#
#                                              title  vote_average  vote_count  \
# 0                                           Avatar           7.2       11800
# 19                                         Titanic           7.5        7562
# ...

# %%
data['ROI'] = np.round( (data['Profit']/data['budget'])*100, 1)

# %%
data.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      Profit     ROI
# 0         4762  2009   Dec  Thursday  2550965087  1076.4
# 1         4763  2007   May  Saturday   661000000   220.3
# ...

# %%
# find the movies with highest ROI.
data_roi = data.sort_values(by='ROI', ascending = False)
data_roi
# Out:
#       Unnamed: 0     id  budget  popularity    revenue                  title  \
# 195          321  43918       0          16  104907746           The Campaign
# 599         1126  44723       0          26   73100172    Here Comes the Boom
# 1315        3407  47004       0          21    7000000  High School Musical 2
# 1313        3404  47001       0          14   41410568             Pale Rider
# 1293        3270  46867       0           5   25966555            Howards End
# ...          ...    ...     ...         ...        ...                    ...
# 1453        4668  48294       0           6          0    She's Gotta Have It
# 1457        4696  48323       0           5          0             The Mighty
# 1459        4732  48359       0           2          0      George Washington
# 1462        4748  48375       0           7          0                Rampage
# 1463        4749  48376       0           3          0                Slacker
#
# ...

# %%
data_roi[data_roi['ROI']< 10000000]
# Out:
#       Unnamed: 0     id    budget  popularity    revenue  \
# 1456        4694  48321     10000          20    7000000
# 1450        4642  48267    400000          33  100000000
# 1102        2409  46006    300000          30   70000000
# 1461        4743  48370     27000          19    3151130
# 1424        4282  47888   1200000          63  103911669
# ...          ...    ...       ...         ...        ...
# 1351        3636  47233   5000000           6          0
# 590         1095  44692       110           9          0
# 1264        3061  46658  10000000          15          0
# 586         1085  44682  45000000          11          0
# 649         1214  44811  40000000          14          0
#
#                            title  vote_average  vote_count  director_id  year  \
# 1456                  Eraserhead           7.5         485         5265  1977
# 1450                     Mad Max           6.6        1213         4845  1979
# ...

# %%
data
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
# step1: what do you want to get from the data?

# %%
data
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
data.iloc[0]
# Out:
# Unnamed: 0               0
# id                   43597
# budget           237000000
# popularity             150
# revenue         2787965087
# title               Avatar
# vote_average           7.2
# vote_count           11800
# director_id           4762
# year                  2009
# month                  Dec
# day               Thursday
# Profit          2550965087
# ROI                 1076.4
# Name: 0, dtype: object

# %%
data.iloc[-1]
# Out:
# Unnamed: 0             4768
# id                    48395
# budget               220000
# popularity               14
# revenue             2040920
# title           El Mariachi
# vote_average            6.6
# vote_count              238
# director_id            5097
# year                   1992
# month                   Sep
# day                  Friday
# Profit              1820920
# ROI                   827.7
# Name: 1464, dtype: object

# %%
data.iloc[1:5]
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day     Profit    ROI
# 1         4763  2007   May  Saturday  661000000  220.3
# 2         4764  2015   Oct    Monday  635674609  259.5
# 3         4765  2012   Jul    Monday  834939099  334.0
# 4         4767  2007   May   Tuesday  632871626  245.3

# %%
data.iloc[1:5][['revenue', 'title']]
# Out:
#       revenue                                     title
# 1   961000000  Pirates of the Caribbean: At World's End
# 2   880674609                                   Spectre
# 3  1084939099                     The Dark Knight Rises
# 4   890871626                              Spider-Man 3

# %%
data.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      Profit     ROI
# 0         4762  2009   Dec  Thursday  2550965087  1076.4
# 1         4763  2007   May  Saturday   661000000   220.3
# ...

# %%
data = data.drop(columns = ['Unnamed: 0', 'day'], axis = 1)

# %%
data.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month      Profit     ROI
# 0         4762  2009   Dec  2550965087  1076.4
# 1         4763  2007   May   661000000   220.3
# 2         4764  2015   Oct   635674609   259.5
# 3         4765  2012   Jul   834939099   334.0
# ...

# %%
# error-> cols don't exists.
# data.drop(columns = ['Unnamed: 0', 'day'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month      Profit     ROI
# 0         4762  2009   Dec  2550965087  1076.4
# 1         4763  2007   May   661000000   220.3
# 2         4764  2015   Oct   635674609   259.5
# 3         4765  2012   Jul   834939099   334.0
# ...

# %%
data
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
year_wise_data = data.groupby(by='year').count()['title']
year_wise_data
# Out:
# year
# 1976     3
# 1977     6
# 1978     5
# 1979     4
# 1980     8
# 1981    11
# 1982    10
# 1983     9
# 1984    10
# 1985    14
# 1986    11
# 1987    12
# 1988    13
# 1989    18
# 1990    18
# 1991    12
# 1992    22
# 1993    18
# 1994    31
# 1995    33
# 1996    46
# 1997    46
# 1998    45
# 1999    64
# 2000    59
# 2001    62
# 2002    69
# 2003    58
# 2004    61
# 2005    71
# 2006    73
# 2007    54
# 2008    67
# 2009    66
# 2010    63
# 2011    67
# 2012    49
# 2013    57
# 2014    53
# 2015    41
# 2016    26
# Name: title, dtype: int64

# %%
year_wise_data.plot();

# %%
director_wise_data = data.groupby(by='director_id').count()['title']
director_wise_data
# Out:
# director_id
# 4762     7
# 4763     7
# 4764     7
# 4765     8
# 4767    11
#         ..
# 5894     5
# 5951     5
# 5970     6
# 6056     5
# 6204     5
# Name: title, Length: 199, dtype: int64

# %%
director_wise_data.head(10).plot(kind='bar');

# %%
director_wise_data.sort_values(ascending = False)
# Out:
# director_id
# 4799    26
# 4809    19
# 5087    19
# 5457    18
# 4779    16
#         ..
# 5105     5
# 4849     5
# 5096     5
# 5088     5
# 6204     5
# Name: title, Length: 199, dtype: int64

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 51.3MB/s]

# %%
directors = pd.read_csv("directors.csv")
directors.head(10)
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male
# 5           5          Sam Raimi  4767   Male
# 6           6       Byron Howard  4768   Male
# 7           7        Joss Whedon  4769   Male
# 8           8        David Yates  4770   Male
# 9           9        Zack Snyder  4771   Male
