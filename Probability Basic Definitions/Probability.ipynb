# %%
import pandas as pd
import numpy as np

# %%
# !wget https://drive.google.com/uc?id=1zBM3idCNWceBMLKMRBTN8aVFAg5U_YH7 -O Sachin_ODI.csv
# Out:
# --2024-02-23 11:11:45--  https://drive.google.com/uc?id=1zBM3idCNWceBMLKMRBTN8aVFAg5U_YH7
# Resolving drive.google.com (drive.google.com)... 172.217.7.46, 2607:f8b0:4025:811::200e
# Connecting to drive.google.com (drive.google.com)|172.217.7.46|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1zBM3idCNWceBMLKMRBTN8aVFAg5U_YH7 [following]
# --2024-02-23 11:11:45--  https://drive.usercontent.google.com/download?id=1zBM3idCNWceBMLKMRBTN8aVFAg5U_YH7
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.164.1, 2607:f8b0:4025:803::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.164.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26440 (26K) [application/octet-stream]
# Saving to: ‘Sachin_ODI.csv’
#
# Sachin_ODI.csv      100%[===================>]  25.82K  --.-KB/s    in 0.001s
#
# ...

# %%
df = pd.read_csv("Sachin_ODI.csv")
df.shape
# Out:
# (360, 14)

# %%
df.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner    Won  century
# 0  1995-02-16   New Zealand  False    False
# 1  1995-02-18  South Africa  False    False
# 2  1995-02-22         India   True    False
# 3  1995-04-05         India   True    False
# 4  1995-04-07      Pakistan  False    False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   runs     360 non-null    int64
#  1   NotOut   360 non-null    int64
#  2   mins     360 non-null    object
#  3   bf       360 non-null    int64
#  4   fours    360 non-null    int64
#  5   sixes    360 non-null    int64
#  6   sr       360 non-null    float64
#  7   Inns     360 non-null    int64
#  8   Opp      360 non-null    object
#  9   Ground   360 non-null    object
#  10  Date     360 non-null    object
#  11  Winner   360 non-null    object
#  12  Won      360 non-null    bool
#  13  century  360 non-null    bool
# dtypes: bool(2), float64(1), int64(6), object(5)
# memory usage: 34.6+ KB

# %%
df.describe()
# Out:
#              runs      NotOut          bf       fours       sixes          sr  \
# count  360.000000  360.000000  360.000000  360.000000  360.000000  360.000000
# mean    43.241667    0.083333   49.394444    4.858333    0.466667   75.295056
# std     42.182452    0.276770   41.348576    4.722900    1.057669   34.980677
# min      0.000000    0.000000    2.000000    0.000000    0.000000    0.000000
# 25%      8.000000    0.000000   15.000000    1.000000    0.000000   57.030000
# 50%     30.000000    0.000000   35.000000    3.000000    0.000000   76.330000
# 75%     67.000000    0.000000   73.500000    8.000000    1.000000   97.822500
# max    200.000000    1.000000  153.000000   25.000000    7.000000  196.550000
#
#              Inns
# count  360.000000
# mean     1.527778
# std      0.499923
# min      1.000000
# 25%      1.000000
# 50%      2.000000
# 75%      2.000000
# max      2.000000

# %%
df.shape
# Out:
# (360, 14)

# %%
df.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner    Won  century
# 0  1995-02-16   New Zealand  False    False
# 1  1995-02-18  South Africa  False    False
# 2  1995-02-22         India   True    False
# 3  1995-04-05         India   True    False
# 4  1995-04-07      Pakistan  False    False

# %%
len(df[(df['Won']==True)])
# Out:
# 184

# %%
len(df[(df['Won']==True)])/len(df)
# Out:
# 0.5111111111111111

# %%
df['Won'].value_counts()
# Out:
# True     184
# False    176
# Name: Won, dtype: int64

# %%
184/360
# Out:
# 0.5111111111111111

# %%
df['Won'].value_counts(normalize = True)
# Out:
# True     0.511111
# False    0.488889
# Name: Won, dtype: float64

# %%
df.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner    Won  century
# 0  1995-02-16   New Zealand  False    False
# 1  1995-02-18  South Africa  False    False
# 2  1995-02-22         India   True    False
# 3  1995-04-05         India   True    False
# 4  1995-04-07      Pakistan  False    False

# %%
df['century'].value_counts()
# Out:
# False    314
# True      46
# Name: century, dtype: int64

# %%
df['century'].value_counts(normalize = True)
# Out:
# False    0.872222
# True     0.127778
# Name: century, dtype: float64

# %%
len(df[df['century']==True])/len(df)
# Out:
# 0.12777777777777777

# %% [markdown]
# Conclusion: There is only 12.7% probability sachin hit the century.

# %%
df[df['century']==True]['Opp'].value_counts()
# Out:
# Sri Lanka       8
# Australia       8
# Pakistan        5
# South Africa    5
# Zimbabwe        5
# Kenya           4
# New Zealand     4
# West Indies     3
# England         2
# Namibia         1
# Bangladesh      1
# Name: Opp, dtype: int64

# %%
df[['century', 'Won']]
# Out:
#      century    Won
# 0      False  False
# 1      False  False
# 2      False   True
# 3      False   True
# 4      False  False
# ..       ...    ...
# 355    False  False
# 356    False   True
# 357    False   True
# 358     True  False
# 359    False   True
#
# [360 rows x 2 columns]

# %%
len(df[(df['century'] == True) & (df['Won']==True)])
# Out:
# 30

# %%
len(df[(df['century'] == True) & (df['Won']==True)]) / len(df)
# Out:
# 0.08333333333333333

# %%
len(df[(df['century'] == True) & (df['Won']==False)]) / len(df)
# Out:
# 0.044444444444444446

# %%
df[['century', 'Won']].value_counts()
# Out:
# century  Won
# False    False    160
#          True     154
# True     True      30
#          False     16
# dtype: int64

# %%
pd.crosstab(index = df['Won'],
            columns = df['century'])
# Out:
# century  False  True
# Won
# False      160     16
# True       154     30

# %%
pd.crosstab(index = df['Won'],
            columns = df['century'],
            margins = True)
# Out:
# century  False  True  All
# Won
# False      160    16  176
# True       154    30  184
# All        314    46  360

# %%
df.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner    Won  century
# 0  1995-02-16   New Zealand  False    False
# 1  1995-02-18  South Africa  False    False
# 2  1995-02-22         India   True    False
# 3  1995-04-05         India   True    False
# 4  1995-04-07      Pakistan  False    False

# %%
df['Ground'].value_counts()[:20].plot(kind='bar');

# %%
# ground->

# %%
# when india plays first inning->


#
